# %%
#!git clone https://github.com/hukenovs/hagrid

# %%
#!pip install -r hagrid/requirements.txt

# %% [markdown]
# ### Imports

# %%
import pandas as pd
from keras.applications import VGG16
from keras.applications.vgg16 import preprocess_input
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import torch
from tensorflow import keras
from sklearn.model_selection import train_test_split
import pytorch2keras
from PIL import Image
from keras_preprocessing.image import img_to_array
import os
# load_img
from keras.utils import load_img

from tensorflow.keras.preprocessing import image_dataset_from_directory

# %%
# https://machinelearningmastery.com/how-to-use-transfer-learning-when-developing-convolutional-neural-network-models/

# %% [markdown]
# ### Data Preprocessing

# %%
base_dir = os.path.join(os.getcwd(), '../Data')

# %%
train_ds = image_dataset_from_directory(base_dir, 
                                        validation_split=0.3,
                                        subset="training",
                                        seed=42,
                                        image_size=(200, 200),
                                        batch_size=32)

val_ds = image_dataset_from_directory(base_dir,
                                        validation_split=0.2,
                                        subset="validation",
                                        seed=42,
                                        image_size=(200, 200),
                                        batch_size=32)
test_ds = image_dataset_from_directory(base_dir,
                                        validation_split=0.1,
                                        subset="validation",
                                        seed=42,
                                        image_size=(200, 200),
                                        batch_size=32)
# Out:
# Found 870 files belonging to 29 classes.
# Using 609 files for training.
# Found 870 files belonging to 29 classes.
# Using 174 files for validation.
# Found 870 files belonging to 29 classes.
# Using 87 files for validation.

# %% [markdown]
# #### Data augmentation

# %%
data_aug = keras.Sequential([
    keras.layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=(200, 200, 3)),
    keras.layers.experimental.preprocessing.RandomRotation(0.2),
    keras.layers.experimental.preprocessing.RandomZoom((-0.2, 0.2), (0.2, 0.2)),
    keras.layers.experimental.preprocessing.RandomContrast(0.2),
    keras.layers.experimental.preprocessing.RandomTranslation((-0.2, 0.2), (-0.2, 0.2))
])

# %% [markdown]
# ### View sample images

# %%
import matplotlib.pyplot as plt

classes = train_ds.class_names
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(classes[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### Apply Preprocessing

# %%
train = train_ds.map(lambda x, y: (data_aug(x, training=True), y))
#val = val_ds.map(lambda x, y: (data_aug(x, training=True), y))
#test = test_ds.map(lambda x, y: (data_aug(x, training=True), y))

AUTOTUNE = tf.data.AUTOTUNE
train = train.prefetch(buffer_size=AUTOTUNE)
val = val_ds.prefetch(buffer_size=AUTOTUNE)
test = test_ds.prefetch(buffer_size=AUTOTUNE)

# %%
# use preprocess_input to normalize the data
train = train.map(lambda x, y: (preprocess_input(x), y))
val = val.map(lambda x, y: (preprocess_input(x), y))
test = test.map(lambda x, y: (preprocess_input(x), y))

# %%
base_model = VGG16(include_top=False, input_shape=(200, 200, 3), weights='imagenet')
image_batch, label_batch = next(iter(train))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# (32, 6, 6, 512)

# %%
base_model.trainable = False
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 200, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 200, 200, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 200, 200, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 100, 100, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 100, 100, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 100, 100, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 50, 50, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 50, 50, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 50, 50, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 50, 50, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 25, 25, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 25, 25, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 25, 25, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 25, 25, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 12, 12, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 6, 6, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
num_classes = len(classes)
predction_layer = keras.layers.Dense(num_classes, activation='softmax')

# %%
inputs = keras.Input(shape=(200, 200, 3))
x = base_model(inputs, training=False)
x = keras.layers.Flatten()(x)
x = keras.layers.Dropout(0.2)(x)
#x = keras.layers.Dense(128, activation='relu')(x)
outputs = predction_layer(x)
model = keras.Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200, 200, 3)]     0
#
#  vgg16 (Functional)          (None, 6, 6, 512)         14714688
#
#  flatten (Flatten)           (None, 18432)             0
#
#  dropout (Dropout)           (None, 18432)             0
#
#  dense (Dense)               (None, 29)                534557
#
# =================================================================
# Total params: 15,249,245
# Trainable params: 534,557
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# compile model
opt = keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# train
epoch = 25
history = model.fit(train, epochs=epoch, validation_data=val)
# Out:
# Epoch 1/25
# 20/20 [==============================] - 42s 2s/step - loss: 11.3422 - accuracy: 0.4384 - val_loss: 12.5706 - val_accuracy: 0.4540
# Epoch 2/25
# 20/20 [==============================] - 39s 2s/step - loss: 11.2955 - accuracy: 0.4762 - val_loss: 9.8022 - val_accuracy: 0.5172
# Epoch 3/25
# 20/20 [==============================] - 43s 2s/step - loss: 9.5530 - accuracy: 0.5074 - val_loss: 9.0455 - val_accuracy: 0.5575
# Epoch 4/25
# 20/20 [==============================] - 42s 2s/step - loss: 8.7991 - accuracy: 0.5731 - val_loss: 11.5967 - val_accuracy: 0.5115
# Epoch 5/25
# 20/20 [==============================] - 43s 2s/step - loss: 7.5035 - accuracy: 0.6125 - val_loss: 9.1844 - val_accuracy: 0.5690
# Epoch 6/25
# 20/20 [==============================] - 45s 2s/step - loss: 6.4912 - accuracy: 0.6683 - val_loss: 11.0932 - val_accuracy: 0.5747
# Epoch 7/25
# 20/20 [==============================] - 43s 2s/step - loss: 7.5882 - accuracy: 0.6519 - val_loss: 9.7889 - val_accuracy: 0.5920
# Epoch 8/25
# 20/20 [==============================] - 43s 2s/step - loss: 6.0483 - accuracy: 0.6634 - val_loss: 12.3223 - val_accuracy: 0.5460
# Epoch 9/25
# 20/20 [==============================] - 44s 2s/step - loss: 7.0257 - accuracy: 0.6831 - val_loss: 14.5151 - val_accuracy: 0.4770
# Epoch 10/25
# 20/20 [==============================] - 44s 2s/step - loss: 5.8008 - accuracy: 0.7044 - val_loss: 11.2019 - val_accuracy: 0.5805
# Epoch 11/25
# 20/20 [==============================] - 42s 2s/step - loss: 5.7400 - accuracy: 0.7126 - val_loss: 8.7405 - val_accuracy: 0.5920
# Epoch 12/25
# 20/20 [==============================] - 45s 2s/step - loss: 5.6749 - accuracy: 0.7159 - val_loss: 11.6902 - val_accuracy: 0.5977
# Epoch 13/25
# 20/20 [==============================] - 43s 2s/step - loss: 5.1142 - accuracy: 0.7422 - val_loss: 10.4700 - val_accuracy: 0.5747
# Epoch 14/25
# 20/20 [==============================] - 43s 2s/step - loss: 5.0558 - accuracy: 0.7603 - val_loss: 12.6949 - val_accuracy: 0.5690
# Epoch 15/25
# 20/20 [==============================] - 39s 2s/step - loss: 5.0539 - accuracy: 0.7603 - val_loss: 11.8098 - val_accuracy: 0.5920
# Epoch 16/25
# 20/20 [==============================] - 39s 2s/step - loss: 6.2085 - accuracy: 0.7110 - val_loss: 10.7620 - val_accuracy: 0.5920
# Epoch 17/25
# 20/20 [==============================] - 42s 2s/step - loss: 5.0234 - accuracy: 0.7685 - val_loss: 12.1298 - val_accuracy: 0.6092
# Epoch 18/25
# 20/20 [==============================] - 42s 2s/step - loss: 4.8499 - accuracy: 0.7586 - val_loss: 10.7985 - val_accuracy: 0.6322
# Epoch 19/25
# 20/20 [==============================] - 41s 2s/step - loss: 4.5615 - accuracy: 0.7734 - val_loss: 12.4037 - val_accuracy: 0.6149
# Epoch 20/25
# 20/20 [==============================] - 42s 2s/step - loss: 4.1923 - accuracy: 0.7964 - val_loss: 10.7621 - val_accuracy: 0.6667
# Epoch 21/25
# 20/20 [==============================] - 40s 2s/step - loss: 5.6196 - accuracy: 0.7553 - val_loss: 13.8508 - val_accuracy: 0.5977
# Epoch 22/25
# 20/20 [==============================] - 43s 2s/step - loss: 5.0473 - accuracy: 0.7685 - val_loss: 12.6982 - val_accuracy: 0.6322
# Epoch 23/25
# 20/20 [==============================] - 42s 2s/step - loss: 5.4063 - accuracy: 0.7652 - val_loss: 13.8560 - val_accuracy: 0.6092
# Epoch 24/25
# 20/20 [==============================] - 46s 2s/step - loss: 3.7190 - accuracy: 0.8424 - val_loss: 11.4407 - val_accuracy: 0.6149
# Epoch 25/25
# 20/20 [==============================] - 40s 2s/step - loss: 3.8548 - accuracy: 0.8161 - val_loss: 9.9934 - val_accuracy: 0.6724

# %%
# evaluate test set
test_loss, test_acc = model.evaluate(test)
# Out:
# 3/3 [==============================] - 5s 2s/step - loss: 20.8350 - accuracy: 0.4828

# %% [markdown]
# ### NN without transfer learning

# %%
# create a new model but don't use transfer learning, make it complicated
epoch = 25
model2 = keras.Sequential([
    keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(200, 200, 3)),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(128, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(128, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.Dense(num_classes, activation='softmax')
])
model2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history2 = model2.fit(train, epochs=epoch, validation_data=val)
# Out:
# Epoch 1/25
# 20/20 [==============================] - 14s 656ms/step - loss: 8.8551 - accuracy: 0.0230 - val_loss: 3.3631 - val_accuracy: 0.0460
# Epoch 2/25
# 20/20 [==============================] - 14s 667ms/step - loss: 3.3548 - accuracy: 0.0328 - val_loss: 3.3585 - val_accuracy: 0.0517
# Epoch 3/25
# 20/20 [==============================] - 14s 704ms/step - loss: 3.3624 - accuracy: 0.0345 - val_loss: 3.3663 - val_accuracy: 0.0345
# Epoch 4/25
# 20/20 [==============================] - 14s 713ms/step - loss: 3.3655 - accuracy: 0.0476 - val_loss: 3.3697 - val_accuracy: 0.0172
# Epoch 5/25
# 20/20 [==============================] - 14s 700ms/step - loss: 3.3639 - accuracy: 0.0460 - val_loss: 3.3711 - val_accuracy: 0.0230
# Epoch 6/25
# 20/20 [==============================] - 14s 705ms/step - loss: 3.3614 - accuracy: 0.0476 - val_loss: 3.3655 - val_accuracy: 0.0172
# Epoch 7/25
# 20/20 [==============================] - 14s 669ms/step - loss: 3.3442 - accuracy: 0.0591 - val_loss: 3.3665 - val_accuracy: 0.0345
# Epoch 8/25
# 20/20 [==============================] - 13s 617ms/step - loss: 3.3454 - accuracy: 0.0591 - val_loss: 3.3792 - val_accuracy: 0.0460
# Epoch 9/25
# 20/20 [==============================] - 13s 616ms/step - loss: 3.3390 - accuracy: 0.0591 - val_loss: 3.4093 - val_accuracy: 0.0345
# Epoch 10/25
# 20/20 [==============================] - 13s 649ms/step - loss: 3.3524 - accuracy: 0.0558 - val_loss: 3.3907 - val_accuracy: 0.0460
# Epoch 11/25
# 20/20 [==============================] - 14s 683ms/step - loss: 3.3638 - accuracy: 0.0427 - val_loss: 3.3818 - val_accuracy: 0.0172
# Epoch 12/25
# 20/20 [==============================] - 14s 700ms/step - loss: 3.3610 - accuracy: 0.0460 - val_loss: 3.3863 - val_accuracy: 0.0287
# Epoch 13/25
# 20/20 [==============================] - 14s 691ms/step - loss: 3.3559 - accuracy: 0.0460 - val_loss: 3.3905 - val_accuracy: 0.0287
# Epoch 14/25
# 20/20 [==============================] - 13s 637ms/step - loss: 3.3546 - accuracy: 0.0509 - val_loss: 3.3861 - val_accuracy: 0.0287
# Epoch 15/25
# 20/20 [==============================] - 14s 677ms/step - loss: 3.3520 - accuracy: 0.0509 - val_loss: 4.6227 - val_accuracy: 0.0345
# Epoch 16/25
# 20/20 [==============================] - 14s 703ms/step - loss: 3.3752 - accuracy: 0.0525 - val_loss: 3.3878 - val_accuracy: 0.0460
# Epoch 17/25
# 20/20 [==============================] - 13s 643ms/step - loss: 3.3574 - accuracy: 0.0558 - val_loss: 3.3919 - val_accuracy: 0.0287
# Epoch 18/25
# 20/20 [==============================] - 13s 625ms/step - loss: 3.3549 - accuracy: 0.0460 - val_loss: 3.3959 - val_accuracy: 0.0172
# Epoch 19/25
# 20/20 [==============================] - 13s 617ms/step - loss: 3.3604 - accuracy: 0.0509 - val_loss: 3.3898 - val_accuracy: 0.0115
# Epoch 20/25
# 20/20 [==============================] - 13s 616ms/step - loss: 3.3583 - accuracy: 0.0460 - val_loss: 3.3867 - val_accuracy: 0.0345
# Epoch 21/25
# 20/20 [==============================] - 13s 641ms/step - loss: 3.3568 - accuracy: 0.0361 - val_loss: 3.3928 - val_accuracy: 0.0345
# Epoch 22/25
# 20/20 [==============================] - 15s 742ms/step - loss: 3.3591 - accuracy: 0.0279 - val_loss: 3.3892 - val_accuracy: 0.0230
# Epoch 23/25
# 20/20 [==============================] - 14s 685ms/step - loss: 3.3456 - accuracy: 0.0394 - val_loss: 3.3781 - val_accuracy: 0.0287
# Epoch 24/25
# 20/20 [==============================] - 13s 651ms/step - loss: 3.3279 - accuracy: 0.0443 - val_loss: 3.4107 - val_accuracy: 0.0345
# Epoch 25/25
# 20/20 [==============================] - 14s 695ms/step - loss: 3.3188 - accuracy: 0.0575 - val_loss: 3.3975 - val_accuracy: 0.0402

# %% [markdown]
# ### Visualize results

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epoch)
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(epochs_range, accuracy, label='Training Accuracy')
plt.plot(epochs_range, val_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy without Transfer Learning')

plt.subplot(2, 1, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='lower right')
plt.title('Training and Validation Loss without Transfer Learning')
plt.show()

# %%
image_batch, label_batch = next(iter(test))
predictions = model.predict(image_batch)

predictions = np.argmax(predictions, axis=1)

plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    plt.title(classes[predictions[i]])
    plt.axis("off")
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
confusion_matrix_actual = []
confusion_matrix_predicted = []

for images, labels in test:
    predictions = model.predict(images)
    predictions = np.argmax(predictions, axis=1)
    confusion_matrix_actual.extend(labels)
    confusion_matrix_predicted.extend(predictions)

from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(confusion_matrix_actual, confusion_matrix_predicted)
plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt="d")
plt.title("Confusion matrix")
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
